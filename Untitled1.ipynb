# %%
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.ops import unary_union, linemerge

gdf = gpd.read_file("C:/Users/isabe/Downloads/clippedcoast.json")

merged = unary_union(gdf.geometry)
coastline = linemerge(merged)

# If still multipart, choose the longest line
if coastline.geom_type == "MultiLineString":
    coastline = max(coastline.geoms, key=lambda line: line.length)
plt.figure(figsize=(6,6))
plt.plot(x, y)
plt.gca().set_aspect("equal", adjustable="box")
plt.title("Main coastline segment")
plt.show()

# %%
coords = np.array(coastline.coords)

x = coords[:, 0]
y = coords[:, 1]

plt.plot(x, y)
plt.axis("equal")
plt.title("Main coastline segment")
plt.show()
