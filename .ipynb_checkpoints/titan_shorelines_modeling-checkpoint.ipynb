# %%
import geopandas as gpd
import numpy as np

gdf = gpd.read_file("C:/Users/isabe/Downloads/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10.shp")

# %%
xmin, xmax = 176.3, 176.8
ymin, ymax = -38, -37.95

subset = gdf.cx[xmin:xmax, ymin:ymax]

subset.plot(figsize=(6,6))
print(subset)
# Out:
#         Hylak_id Lake_name      Country Continent Poly_src  Lake_type  \
# 184966    184967      None  New Zealand   Oceania     SWBD          1
#
#         Grand_id  Lake_area  Shore_len  Shore_dev  ...  Vol_src  Depth_avg  \
# 184966         0       7.35      29.98       3.12  ...        3       18.3
#
#         Dis_avg  Res_time  Elevation  Slope_100  Wshd_area   Pour_long  \
# 184966     2.58     604.0        300       7.57       78.6  176.512108
#
#          Pour_lat                                           geometry
# 184966 -38.034299  POLYGON ((176.53047 -37.99372, 176.53153 -37.9...
#
# [1 rows x 22 columns]

# %%
lake = gdf[gdf["Lake_name"] == "Superior"]

# %%
lake = gdf[gdf["Hylak_id"] == 184967]

# %%
geom = lake.geometry.iloc[0]

coords = geom.exterior.coords  # polygon boundary
coords = list(coords)

x = [c[0] for c in coords]
y = [c[1] for c in coords]

# %%
import matplotlib.pyplot as plt

plt.plot(x, y)
plt.axis("equal")
plt.title("Lake Superior coastline")
plt.show()

# %%
k = 0.1       # erosion coefficient
dt = 0.1      # time step
steps = 300   # number of iterations

coast = lake
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 dt = 0.1      # time step
#       3 steps = 300   # number of iterations
# ----> 5 coast = lake
#
# NameError: name 'lake' is not defined

# %%
plt.plot(coast)
plt.title("initial rough coastline before erosion")
plt.xlabel("distance")
plt.ylabel("shoreline position")
plt.show()
